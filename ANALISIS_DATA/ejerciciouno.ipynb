# %%
import pandas as pd
datos=pd.DataFrame({"producto":["Manzana","Pan","Leche","huevos","Naranja"],
                   "precio":[1000,1200,5000,1800,1000],
                   "stock":[80,100,50,40,20]})
datos
# Out:
#   producto  precio  stock
# 0  Manzana    1000     80
# 1      Pan    1200    100
# 2    Leche    5000     50
# 3   huevos    1800     40
# 4  Naranja    1000     20

# %%
datos.head()
# Out:
#   producto  precio  stock
# 0  Manzana    1000     80
# 1      Pan    1200    100
# 2    Leche    5000     50
# 3   huevos    1800     40
# 4  Naranja    1000     20

# %%
datos.tail()
# Out:
#   producto  precio  stock
# 0  Manzana    1000     80
# 1      Pan    1200    100
# 2    Leche    5000     50
# 3   huevos    1800     40
# 4  Naranja    1000     20

# %%
datos.shape
# Out:
# (5, 3)

# %%
datos.dtypes
# Out:
# producto      str
# precio      int64
# stock       int64
# dtype: object

# %%
datos["precio"]
# Out:
# 0    1000
# 1    1200
# 2    5000
# 3    1800
# 4    1000
# Name: precio, dtype: int64

# %%
datos[["precio", "producto"]]
# Out:
#    precio producto
# 0    1000  Manzana
# 1    1200      Pan
# 2    5000    Leche
# 3    1800   huevos
# 4    1000  Naranja

# %%
datos.loc[0]
# Out:
# producto    Manzana
# precio         1000
# stock            80
# Name: 0, dtype: object

# %%
datos.loc[1:3]
# Out:
#   producto  precio  stock
# 1      Pan    1200    100
# 2    Leche    5000     50
# 3   huevos    1800     40

# %%
datos.iloc[0]
# Out:
# producto    Manzana
# precio         1000
# stock            80
# Name: 0, dtype: object

# %%
datos.loc[0:2, "producto"]
# Out:
# 0    Manzana
# 1        Pan
# 2      Leche
# Name: producto, dtype: str

# %%
datos.loc[0:2, ["producto", "precio"]]
# Out:
#   producto  precio
# 0  Manzana    1000
# 1      Pan    1200
# 2    Leche    5000

# %%
datos[datos["precio"]>1000]
# Out:
#   producto  precio  stock
# 1      Pan    1200    100
# 2    Leche    5000     50
# 3   huevos    1800     40

# %%
datos[(datos["precio"]>1000) & (datos["stock"]<50)]
# Out:
#   producto  precio  stock
# 3   huevos    1800     40

# %%
datos["valor_total"] = datos["precio"] * datos["stock"]
datos
# Out:
#   producto  precio  stock  valor_total
# 0  Manzana    1000     80        80000
# 1      Pan    1200    100       120000
# 2    Leche    5000     50       250000
# 3   huevos    1800     40        72000
# 4  Naranja    1000     20        20000

# %%
datos["ciudad"] = "Barranquilla"
datos
# Out:
#   producto  precio  stock  valor_total        ciudad
# 0  Manzana    1000     80        80000  Barranquilla
# 1      Pan    1200    100       120000  Barranquilla
# 2    Leche    5000     50       250000  Barranquilla
# 3   huevos    1800     40        72000  Barranquilla
# 4  Naranja    1000     20        20000  Barranquilla

# %%
datos.loc[0, "precio"] = 13500
datos
# Out:
#   producto  precio  stock  valor_total        ciudad
# 0  Manzana   13500     80        80000  Barranquilla
# 1      Pan    1200    100       120000  Barranquilla
# 2    Leche    5000     50       250000  Barranquilla
# 3   huevos    1800     40        72000  Barranquilla
# 4  Naranja    1000     20        20000  Barranquilla

# %%
datos.loc[1, "stock"] = 80
datos
# Out:
#   producto  precio  stock  valor_total        ciudad
# 0  Manzana   13500     80        80000  Barranquilla
# 1      Pan    1200     80       120000  Barranquilla
# 2    Leche    5000     50       250000  Barranquilla
# 3   huevos    1800     40        72000  Barranquilla
# 4  Naranja    1000     20        20000  Barranquilla

# %%
datos.drop(columns="ciudad", inplace=True)

# %%
datos
# Out:
#   producto  precio  stock  valor_total
# 0  Manzana   13500     80        80000
# 1      Pan    1200     80       120000
# 2    Leche    5000     50       250000
# 3   huevos    1800     40        72000
# 4  Naranja    1000     20        20000

# %%
datos["descuento"]= datos["valor_total"]*0.10

# %%
datos
# Out:
#   producto  precio  stock  valor_total  descuento
# 0  Manzana   13500     80        80000     8000.0
# 1      Pan    1200     80       120000    12000.0
# 2    Leche    5000     50       250000    25000.0
# 3   huevos    1800     40        72000     7200.0
# 4  Naranja    1000     20        20000     2000.0

# %%
datos.drop(columns="descuento")
# Out:
#   producto  precio  stock  valor_total
# 0  Manzana   13500     80        80000
# 1      Pan    1200     80       120000
# 2    Leche    5000     50       250000
# 3   huevos    1800     40        72000
# 4  Naranja    1000     20        20000

# %%
datos["IVA"] = datos["valor_total"]*0.19

# %%
datos
# Out:
#   producto  precio  stock  valor_total  descuento      IVA
# 0  Manzana   13500     80        80000     8000.0  15200.0
# 1      Pan    1200     80       120000    12000.0  22800.0
# 2    Leche    5000     50       250000    25000.0  47500.0
# 3   huevos    1800     40        72000     7200.0  13680.0
# 4  Naranja    1000     20        20000     2000.0   3800.0

# %%
datos = datos.drop(columns="IVA")

# %%
datos.isnull().sum()
# Out:
# producto       0
# precio         0
# stock          0
# valor_total    0
# descuento      0
# dtype: int64

# %%
datos.rename(columns={"precio":"precio_unidad"})
# Out:
#   producto  precio_unidad  stock  valor_total  descuento
# 0  Manzana          13500     80        80000     8000.0
# 1      Pan           1200     80       120000    12000.0
# 2    Leche           5000     50       250000    25000.0
# 3   huevos           1800     40        72000     7200.0
# 4  Naranja           1000     20        20000     2000.0

# %%
datos[(datos["producto"]=="Manzana")| (datos["producto"]=="huevos")]
# Out:
#   producto  precio  stock  valor_total  descuento
# 0  Manzana   13500     80        80000     8000.0
# 3   huevos    1800     40        72000     7200.0

# %%
datos[((datos["producto"] == "Manzana")| (datos["producto"] == "huevos")) & (datos["valor_total"]>75000)]
# Out:
#   producto  precio  stock  valor_total  descuento
# 0  Manzana   13500     80        80000     8000.0

# %%
datos[~((datos["producto"] == "Naranja") | (datos["producto"] == "Leche"))]
# Out:
#   producto  precio  stock  valor_total  descuento
# 0  Manzana   13500     80        80000     8000.0
# 1      Pan    1200     80       120000    12000.0
# 3   huevos    1800     40        72000     7200.0

# %%
datos.query("precio > 1000")
# Out:
#   producto  precio  stock  valor_total  descuento
# 0  Manzana   13500     80        80000     8000.0
# 1      Pan    1200     80       120000    12000.0
# 2    Leche    5000     50       250000    25000.0
# 3   huevos    1800     40        72000     7200.0

# %%
df = datos.rename(columns={"precio":"Precio_unidad"})

# %%
df.query("Precio_unidad <20000 | producto == 'Manzana'")
# Out:
#   producto  Precio_unidad  stock  valor_total  descuento
# 0  Manzana          13500     80        80000     8000.0
# 1      Pan           1200     80       120000    12000.0
# 2    Leche           5000     50       250000    25000.0
# 3   huevos           1800     40        72000     7200.0
# 4  Naranja           1000     20        20000     2000.0

# %%
df.sort_values("Precio_unidad", ascending=False)
# Out:
#   producto  Precio_unidad  stock  valor_total  descuento
# 0  Manzana          13500     80        80000     8000.0
# 2    Leche           5000     50       250000    25000.0
# 3   huevos           1800     40        72000     7200.0
# 1      Pan           1200     80       120000    12000.0
# 4  Naranja           1000     20        20000     2000.0
